# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from utility.graphing_tools import single_dim_comparison, compare_across_dims

# %% [markdown]
# # Data import

# %%
## Import data
### Gaussian
scaled_shortcut_gaussian = pd.read_csv("syn_exps/gaussian/scaled_shortcut_gaussian.csv")
standardized_shortcut_gaussian = pd.read_csv("syn_exps/gaussian/standardized_shortcut_gaussian.csv")
scaled_baseline_gaussian = pd.read_csv("syn_exps/gaussian/scaled_baseline_gaussian.csv")
standardized_baseline_gaussian = pd.read_csv("syn_exps/gaussian/standardized_baseline_gaussian.csv")

df_dict_gaussian = {
    "Scaled-Splitting": scaled_baseline_gaussian,
    "Standardized-Splitting": standardized_baseline_gaussian,
    "Scaled-Shortcut": scaled_shortcut_gaussian,
    "Standardized-Shortcut": standardized_shortcut_gaussian
}

### Unit Gaussian
scaled_shortcut_unit_gaussian = pd.read_csv("syn_exps/gaussian/scaled_shortcut_unit_gaussian.csv")
standardized_shortcut_unit_gaussian = pd.read_csv("syn_exps/gaussian/standardized_shortcut_unit_gaussian.csv")
scaled_baseline_unit_gaussian = pd.read_csv("syn_exps/gaussian/scaled_baseline_unit_gaussian.csv")
standardized_baseline_unit_gaussian = pd.read_csv("syn_exps/gaussian/standardized_baseline_unit_gaussian.csv")

df_dict_unit_gaussian = {
    "Scaled-Splitting": scaled_baseline_unit_gaussian,
    "Standardized-Splitting": standardized_baseline_unit_gaussian,
    "Scaled-Shortcut": scaled_shortcut_unit_gaussian,
    "Standardized-Shortcut": standardized_shortcut_unit_gaussian
}

### Laplace
scaled_shortcut_laplace = pd.read_csv("syn_exps/laplace/scaled_shortcut_laplace.csv")
standardized_shortcut_laplace = pd.read_csv("syn_exps/laplace/standardized_shortcut_laplace.csv")
scaled_baseline_laplace = pd.read_csv("syn_exps/laplace/scaled_baseline_laplace.csv")
standardized_baseline_laplace = pd.read_csv("syn_exps/laplace/standardized_baseline_laplace.csv")

df_dict_laplace = {
    "Scaled-Splitting": scaled_baseline_laplace,
    "Standardized-Splitting": standardized_baseline_laplace,
    "Scaled-Shortcut": scaled_shortcut_laplace,
    "Standardized-Shortcut": standardized_shortcut_laplace
}

### Mixed
scaled_shortcut_mixed = pd.read_csv("syn_exps/mixed/scaled_shortcut_mixed.csv")
standardized_shortcut_mixed = pd.read_csv("syn_exps/mixed/standardized_shortcut_mixed.csv")
scaled_baseline_mixed = pd.read_csv("syn_exps/mixed/scaled_baseline_mixed.csv")
standardized_baseline_mixed = pd.read_csv("syn_exps/mixed/standardized_baseline_mixed.csv")

df_dict_mixed = {
    "Scaled-Splitting": scaled_baseline_mixed,
    "Standardized-Splitting": standardized_baseline_mixed,
    "Scaled-Shortcut": scaled_shortcut_mixed,
    "Standardized-Shortcut": standardized_shortcut_mixed
}

### Gamma
scaled_shortcut_gamma = pd.read_csv("syn_exps/gamma/scaled_shortcut_gamma.csv")
standardized_shortcut_gamma = pd.read_csv("syn_exps/gamma/standardized_shortcut_gamma.csv")
scaled_baseline_gamma = pd.read_csv("syn_exps/gamma/scaled_baseline_gamma.csv")
standardized_baseline_gamma = pd.read_csv("syn_exps/gamma/standardized_baseline_gamma.csv")

df_dict_gamma = {
    "Scaled-Splitting": scaled_baseline_gamma,
    "Standardized-Splitting": standardized_baseline_gamma,
    "Scaled-Shortcut": scaled_shortcut_gamma,
    "Standardized-Shortcut": standardized_shortcut_gamma
}

# %% [markdown]
# # Comparison across all distributions between scaled method and standardized method

# %% [markdown]
# ## Gaussian

# %% [markdown]
# ### Low dim: d=2

# %%
single_dim_comparison(df_dict_gaussian, 2, error_bar=False)
# Out:
# (<Figure size 1200x450 with 3 Axes>,
#  array([<Axes: title={'center': 'Test Coverage'}>,
#         <Axes: title={'center': 'Volume'}, xlabel='No. of Calibration Points'>,
#         <Axes: title={'center': 'Runtime ($\\log_{10}$-Scale)'}>],
#        dtype=object))

# %% [markdown]
# ### High dim: d=20

# %%
single_dim_comparison(df_dict_gaussian, 20, error_bar=False)
# Out:
# (<Figure size 1200x450 with 3 Axes>,
#  array([<Axes: title={'center': 'Test Coverage'}>,
#         <Axes: title={'center': 'Volume'}, xlabel='No. of Calibration Points'>,
#         <Axes: title={'center': 'Runtime ($\\log_{10}$-Scale)'}>],
#        dtype=object))

# %% [markdown]
# ### Fixed $n$, increasing $d$

# %%
# n=30
compare_across_dims(df_dict_gaussian, 30, error_bar=False)
# Out:
# (<Figure size 1200x450 with 3 Axes>,
#  array([<Axes: title={'center': 'Test Coverage'}>,
#         <Axes: title={'center': 'Volume'}, xlabel='No. of Dimensions'>,
#         <Axes: title={'center': 'Runtime ($\\log_{10}$-Scale)'}>],
#        dtype=object))

# %%
#n=100
compare_across_dims(df_dict_gaussian, 100, error_bar=False)
# Out:
# (<Figure size 1200x450 with 3 Axes>,
#  array([<Axes: title={'center': 'Test Coverage'}>,
#         <Axes: title={'center': 'Volume'}, xlabel='No. of Dimensions'>,
#         <Axes: title={'center': 'Runtime ($\\log_{10}$-Scale)'}>],
#        dtype=object))

# %% [markdown]
# ## Laplace

# %% [markdown]
# ### Low dim: d=2

# %%
single_dim_comparison(df_dict_laplace, 2, error_bar=False)
# Out:
# (<Figure size 1200x450 with 3 Axes>,
#  array([<Axes: title={'center': 'Test Coverage'}>,
#         <Axes: title={'center': 'Volume'}, xlabel='No. of Calibration Points'>,
#         <Axes: title={'center': 'Runtime ($\\log_{10}$-Scale)'}>],
#        dtype=object))

# %% [markdown]
# ### High dim: n=20

# %%
single_dim_comparison(df_dict_laplace, 20, error_bar=False)
# Out:
# (<Figure size 1200x450 with 3 Axes>,
#  array([<Axes: title={'center': 'Test Coverage'}>,
#         <Axes: title={'center': 'Volume'}, xlabel='No. of Calibration Points'>,
#         <Axes: title={'center': 'Runtime ($\\log_{10}$-Scale)'}>],
#        dtype=object))

# %% [markdown]
# ### Fixed $n$, increasing $d$

# %%
#n=30
compare_across_dims(df_dict_laplace, 30, error_bar=False)
# Out:
# (<Figure size 1200x450 with 3 Axes>,
#  array([<Axes: title={'center': 'Test Coverage'}>,
#         <Axes: title={'center': 'Volume'}, xlabel='No. of Dimensions'>,
#         <Axes: title={'center': 'Runtime ($\\log_{10}$-Scale)'}>],
#        dtype=object))

# %%
#n=100
compare_across_dims(df_dict_laplace, 100, error_bar=False)
# Out:
# (<Figure size 1200x450 with 3 Axes>,
#  array([<Axes: title={'center': 'Test Coverage'}>,
#         <Axes: title={'center': 'Volume'}, xlabel='No. of Dimensions'>,
#         <Axes: title={'center': 'Runtime ($\\log_{10}$-Scale)'}>],
#        dtype=object))

# %% [markdown]
# ## Mixed: half targets gaussian and half targets laplace

# %% [markdown]
# ### Low dim: d=2

# %%
single_dim_comparison(df_dict_mixed, 2, error_bar=False)
# Out:
# (<Figure size 1200x450 with 3 Axes>,
#  array([<Axes: title={'center': 'Test Coverage'}>,
#         <Axes: title={'center': 'Volume'}, xlabel='No. of Calibration Points'>,
#         <Axes: title={'center': 'Runtime ($\\log_{10}$-Scale)'}>],
#        dtype=object))

# %% [markdown]
# ### High dim: n=20

# %%
single_dim_comparison(df_dict_mixed, 20, error_bar=False)
# Out:
# (<Figure size 1200x450 with 3 Axes>,
#  array([<Axes: title={'center': 'Test Coverage'}>,
#         <Axes: title={'center': 'Volume'}, xlabel='No. of Calibration Points'>,
#         <Axes: title={'center': 'Runtime ($\\log_{10}$-Scale)'}>],
#        dtype=object))

# %% [markdown]
# ### Fixed $n$, increasing $d$

# %%
#n=30
compare_across_dims(df_dict_mixed, 30, error_bar=False)
# Out:
# (<Figure size 1200x450 with 3 Axes>,
#  array([<Axes: title={'center': 'Test Coverage'}>,
#         <Axes: title={'center': 'Volume'}, xlabel='No. of Dimensions'>,
#         <Axes: title={'center': 'Runtime ($\\log_{10}$-Scale)'}>],
#        dtype=object))

# %%
#n=30
compare_across_dims(df_dict_mixed, 100, error_bar=False)
# Out:
# (<Figure size 1200x450 with 3 Axes>,
#  array([<Axes: title={'center': 'Test Coverage'}>,
#         <Axes: title={'center': 'Volume'}, xlabel='No. of Dimensions'>,
#         <Axes: title={'center': 'Runtime ($\\log_{10}$-Scale)'}>],
#        dtype=object))

# %% [markdown]
# ## Gamma

# %% [markdown]
# ### Low dim: d=2

# %%
single_dim_comparison(df_dict_gamma, 2, error_bar=False)
# Out:
# (<Figure size 1200x450 with 3 Axes>,
#  array([<Axes: title={'center': 'Test Coverage'}>,
#         <Axes: title={'center': 'Volume'}, xlabel='No. of Calibration Points'>,
#         <Axes: title={'center': 'Runtime ($\\log_{10}$-Scale)'}>],
#        dtype=object))

# %% [markdown]
# ### High dim: d=20

# %%
single_dim_comparison(df_dict_mixed, 20, error_bar=False)
# Out:
# (<Figure size 1200x450 with 3 Axes>,
#  array([<Axes: title={'center': 'Test Coverage'}>,
#         <Axes: title={'center': 'Volume'}, xlabel='No. of Calibration Points'>,
#         <Axes: title={'center': 'Runtime ($\\log_{10}$-Scale)'}>],
#        dtype=object))

# %% [markdown]
# ### Fixed $n$, increasing $d$

# %%
#n=30
compare_across_dims(df_dict_gamma, 30, error_bar=False)
# Out:
# (<Figure size 1200x450 with 3 Axes>,
#  array([<Axes: title={'center': 'Test Coverage'}>,
#         <Axes: title={'center': 'Volume'}, xlabel='No. of Dimensions'>,
#         <Axes: title={'center': 'Runtime ($\\log_{10}$-Scale)'}>],
#        dtype=object))

# %%
#n=100
compare_across_dims(df_dict_gamma, 100, error_bar=False)
# Out:
# (<Figure size 1200x450 with 3 Axes>,
#  array([<Axes: title={'center': 'Test Coverage'}>,
#         <Axes: title={'center': 'Volume'}, xlabel='No. of Dimensions'>,
#         <Axes: title={'center': 'Runtime ($\\log_{10}$-Scale)'}>],
#        dtype=object))
